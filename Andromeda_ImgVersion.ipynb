# %% [markdown]
# # Andromeda with Image Data in Jupyter

# %%
# %matplotlib widget
from utils import *
hide_toggle(for_next=True)
# Out:
# 20 images loaded
# <style>.container { width:95% !important; }</style>
# <style>.output_result { max-width:100% !important; }</style>
# <style>.prompt { display:none !important; }</style>
#         <script>
#             function code_toggle_7632302443509701600() {
#                 $('div.cell.code_cell.rendered.selected').next().find('div.input').toggle();
#             }
#
#             $('div.cell.code_cell.rendered.selected').find("div.input").hide();
#         </script>
#
#         <a href="javascript:code_toggle_7632302443509701600()">Toggle show/hide next cell</a>

# %%
plot_ax = create_plot(df_2D, imgDisplaySize)
hide_toggle(for_next=True)
# Out:
#         <script>
#             function code_toggle_11227108708217121101() {
#                 $('div.cell.code_cell.rendered.selected').next().find('div.input').toggle();
#             }
#
#             $('div.cell.code_cell.rendered.selected').find("div.input").hide();
#         </script>
#
#         <a href="javascript:code_toggle_11227108708217121101()">Toggle show/hide next cell</a>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
size_slider = create_size_slider(imgDisplaySize)
sliders = create_sliders(weights)
size_apply_button = create_size_slider_button(size_slider,plot_ax)
hide_toggle(for_next=True)
# Out:
# FloatSlider(value=1e-05, continuous_update=False, description='Eccentricity', layout=Layout(height='10px', wid…
# FloatSlider(value=1e-05, continuous_update=False, description='Aspect Ratio', layout=Layout(height='10px', wid…
# FloatSlider(value=1e-05, continuous_update=False, description='Elongation', layout=Layout(height='10px', width…
# FloatSlider(value=1e-05, continuous_update=False, description='Solidity', layout=Layout(height='10px', width='…
# FloatSlider(value=1e-05, continuous_update=False, description='Stochastic Convexity', layout=Layout(height='10…
# FloatSlider(value=1e-05, continuous_update=False, description='Isoperimetric Factor', layout=Layout(height='10…
# FloatSlider(value=1e-05, continuous_update=False, description='Maximal Indentation Depth', layout=Layout(heigh…
# FloatSlider(value=1e-05, continuous_update=False, description='Lobedness', layout=Layout(height='10px', width=…
# FloatSlider(value=1e-05, continuous_update=False, description='Average Intensity', layout=Layout(height='10px'…
# FloatSlider(value=1e-05, continuous_update=False, description='Average Contrast', layout=Layout(height='10px',…
# FloatSlider(value=1e-05, continuous_update=False, description='Smoothness', layout=Layout(height='10px', width…
# FloatSlider(value=1e-05, continuous_update=False, description='Third Moment', layout=Layout(height='10px', wid…
# FloatSlider(value=1e-05, continuous_update=False, description='Uniformity', layout=Layout(height='10px', width…
# FloatSlider(value=1e-05, continuous_update=False, description='Entropy', layout=Layout(height='10px', width='6…
#         <script>
#             function code_toggle_13080507968217125423() {
#                 $('div.cell.code_cell.rendered.selected').next().find('div.input').toggle();
#             }
#
#             $('div.cell.code_cell.rendered.selected').find("div.input").hide();
#         </script>
#
#         <a href="javascript:code_toggle_13080507968217125423()">Toggle show/hide next cell</a>

# %%
point_attribute = create_checkbox(size_slider, plot_ax)
inverse_button, copy_button = create_inverse_button(plot_ax, size_slider, sliders)
display(widgets.HBox([inverse_button, copy_button,create_reset_buttons(plot_ax, size_slider, sliders),
                      create_slider_buttons(sliders,size_slider, plot_ax)]))
display(widgets.HBox([size_slider,size_apply_button]))
# Out:
# interactive(children=(Checkbox(value=False, description='Toggle Titles', indent=False, layout=Layout(height='2…
# interactive(children=(Checkbox(value=True, description='Toggle Images', indent=False, layout=Layout(height='20…
# HBox(children=(Button(description='Learn New Weights', style=ButtonStyle(button_color='darkseagreen')), Button…
# HBox(children=(FloatSlider(value=0.35, continuous_update=False, description='Adjust image size', max=1.0, read…
